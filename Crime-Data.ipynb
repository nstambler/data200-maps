# %%
#Imports cvs and splits department_name into two columns
import pandas as pd
crime = pd.read_csv('/Users/nikolaistambler/Library/Application Support/JetBrains/PyCharmEdu2020.1/scratches/crime.csv')
crime[['City','State']] =  crime.department_name.str.split(",", expand=True)

#Drops all unnecessary columns
crime = crime.drop(columns = ["Unnamed: 0", "department_name", "total_pop", "homs_sum", "rape_sum", "rob_sum", "agg_ass_sum", "violent_crime", "months_reported","violent_per_100k","rape_per_100k", "rob_per_100k", "agg_ass_per_100k"])

#Creates three different datasets (based on year)
crime_1975 = crime[(crime.year == 1975)]
crime_1995 = crime[(crime.year == 1995)]
crime_2014 = crime[(crime.year == 2014)]

from opencage.geocoder import OpenCageGeocode
key = 'b59b13e931c54e949b2155ad995008ad'
geocoder = OpenCageGeocode(key)


list_lat_75 = []   # create empty lists

list_long_75 = []

for index, row in crime_1975.iterrows():
    City = row['City']
    results = geocoder.geocode(City)
    lat = results[0]['geometry']['lat']
    long = results[0]['geometry']['lng']
    list_lat_75.append(lat)
    list_long_75.append(long)
crime_1975['lat'] = list_lat_75
crime_1975['long'] = list_long_75

crime_1975.head(5)

# create new columns from lists

list_lat_95 = []   # create empty lists

list_long_95 = []

for index, row in crime_1995.iterrows():
    City = row['City']
    results = geocoder.geocode(City)
    lat = results[0]['geometry']['lat']
    long = results[0]['geometry']['lng']
    list_lat_95.append(lat)
    list_long_95.append(long)
crime_1995['lat'] = list_lat_95
crime_1995['long'] = list_long_95

crime_1995.head(5)


list_lat_14 = []   # create empty lists

list_long_14 = []

for index, row in crime_2014.iterrows():
    City = row['City']
    results = geocoder.geocode(City)
    lat = results[0]['geometry']['lat']
    long = results[0]['geometry']['lng']
    list_lat_14.append(lat)
    list_long_14.append(long)
crime_2014['lat'] = list_lat_14
crime_2014['long'] = list_long_14

crime_2014.head(5)

crime_1975 = crime_1975.drop(columns = ["year"])
crime_1995 = crime_1995.drop(columns = ["year"])
crime_2014 = crime_2014.drop(columns = ["year"])

loc_1975 = crime_1975[['lat','long']].copy()
loc_1995 = crime_1995[['lat','long']].copy()
loc_2014 = crime_2014[['lat', 'long']].copy()

import numpy as np
locations_75 = np.array(loc_1975)
locations_95 = np.array(loc_1995)
locations_14 = np.array(loc_2014)

import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyBblVh51qwkxg6mhZcbWmjCd8WA8-qW3X4") 
weights = crime_1975["homs_per_100k"]
fig = gmaps.figure()
heatmap_layer = gmaps.heatmap_layer(locations_75, weights= weights)
fig.add_layer(heatmap_layer)
fig
# Out:
# <ipython-input-4-79401be3e7ce>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_1975['lat'] = list_lat_75
# <ipython-input-4-79401be3e7ce>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_1975['long'] = list_long_75
# <ipython-input-4-79401be3e7ce>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
